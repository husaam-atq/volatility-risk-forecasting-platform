# %% [markdown]
# # Regime Detection And Dashboard Queries

# %% [markdown]
# Run regime detection and inspect dashboard SQL views.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / "src"))

from volatility_platform.regimes.volatility_regimes import run_regime_detection
from volatility_platform.utils.performance import run_sql_benchmarks
run_regime_detection()
run_sql_benchmarks()

# %%
import duckdb
from volatility_platform.config import DATABASE_PATH
con = duckdb.connect(str(DATABASE_PATH), read_only=True)
con.execute('SELECT * FROM regime_metrics ORDER BY top_decile_capture DESC').fetchdf()

# %%
con.execute('SELECT * FROM v_validation_dashboard_queries').fetchdf()
