# %% [markdown]
# # VaR And ES Backtesting

# %% [markdown]
# Convert volatility forecasts into VaR/ES and run risk backtests.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / "src"))

from volatility_platform.risk.var import run_var_backtest
from volatility_platform.risk.portfolio_risk import build_portfolio_risk
run_var_backtest()
build_portfolio_risk().head()

# %%
import duckdb
from volatility_platform.config import DATABASE_PATH
con = duckdb.connect(str(DATABASE_PATH), read_only=True)
con.execute('SELECT * FROM v_var_breach_summary ORDER BY model, asset, confidence_level').fetchdf().head(20)
