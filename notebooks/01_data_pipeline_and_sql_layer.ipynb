# %% [markdown]
# # Data Pipeline And SQL Layer

# %% [markdown]
# Build the DuckDB database and inspect SQL-backed tables and views.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / "src"))

from volatility_platform.database.build_database import build_database
build_database()

# %%
import duckdb
from volatility_platform.config import DATABASE_PATH
con = duckdb.connect(str(DATABASE_PATH), read_only=True)
con.execute('SELECT * FROM v_dashboard_overview').fetchdf()

# %%
con.execute('SELECT * FROM v_asset_coverage ORDER BY asset').fetchdf()
