# %% [markdown]
# # Volatility Forecasting Models

# %% [markdown]
# Run the forecasting pipeline and compare model metrics.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / "src"))

from volatility_platform.models.walk_forward import run_forecasting_pipeline
run_forecasting_pipeline()

# %%
import duckdb
from volatility_platform.config import DATABASE_PATH
con = duckdb.connect(str(DATABASE_PATH), read_only=True)
con.execute('SELECT * FROM v_model_rank_summary ORDER BY avg_qlike').fetchdf()

# %%
con.execute("SELECT target_date, realised_vol, forecast_vol, model FROM v_forecast_vs_realised WHERE asset='SPY' AND period='test'").fetchdf().head()
